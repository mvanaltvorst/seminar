# %%
# %load_ext autoreload
# %autoreload 2

# %%
import numpy as np
import pandas as pd
from seminartools.data import read_merged
from seminartools.models.var_model import VARModel

# %%
df = read_merged().reset_index()
# Out:
# /Users/philipphocker/Documents/GitHub/seminar/seminartools/data.py:161: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df = df.resample("Q").apply(lambda x: (1 + x).prod() - 1)  # quarterly return
# /Users/philipphocker/Documents/GitHub/seminar/seminartools/data.py:397: FutureWarning: 'Q' is deprecated and will be removed in a future version, please use 'QE' instead.
#   df = df.resample("Q").mean()  # Mean interest rate

# %%
df.head()
# Out:
#          country       date  inflation  gdp_growth  interest_rate  \
# 0          Japan 1977-01-01   0.022951    2.187257       6.333333
# 1         Canada 1977-01-01   0.023904    1.533830       8.166667
# 2  United States 1977-01-01   0.017231    1.186233       4.700000
# 3          Japan 1977-04-01   0.027244    0.703788       5.000000
# 4         Canada 1977-04-01   0.023346    0.510302       7.666667
#
#    unemployment_rate  commodity_CRUDE_PETRO  commodity_iNATGAS  \
# 0                2.3                  0.000           0.052425
# 1                8.8                  0.000           0.052425
# 2                8.2                  0.000           0.052425
# 3                2.0                 -0.004           0.043586
# 4                8.0                 -0.004           0.043586
#
#    commodity_iAGRICULTURE  commodity_iMETMIN  commodity_iPRECIOUSMET
# 0                0.144757           0.041940                0.112740
# 1                0.144757           0.041940                0.112740
# 2                0.144757           0.041940                0.112740
# 3               -0.066688          -0.045412               -0.060029
# 4               -0.066688          -0.045412               -0.060029

# %%
df['country'].unique()
# Out:
# array(['Japan', 'Canada', 'United States', 'Australia', 'New Zealand',
#        'Switzerland', 'Italy', 'France', 'Portugal', 'Spain', 'Sweden',
#        'Denmark', 'United Kingdom', 'Germany', 'Netherlands', 'Norway',
#        'Belgium', 'Korea', 'South Africa', 'Türkiye'], dtype=object)

# %%
df.pivot(index='date', columns='country', values='inflation')
# Out:
# country     Australia   Belgium    Canada   Denmark    France   Germany  \
# date
# 1977-01-01        NaN       NaN  0.023904       NaN       NaN       NaN
# 1977-04-01        NaN       NaN  0.023346       NaN       NaN       NaN
# 1977-07-01        NaN       NaN  0.022814       NaN       NaN       NaN
# 1977-10-01        NaN       NaN  0.018587       NaN       NaN       NaN
# 1978-01-01        NaN       NaN  0.021898       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# 2022-01-01   0.021295  0.033275  0.020211  0.021536  0.014870  0.018498
# 2022-04-01   0.017376  0.016949  0.031008  0.032997  0.022894  0.028500
# 2022-07-01   0.017933  0.025000  0.008354  0.023957  0.011638  0.016134
# 2022-10-01   0.019102  0.030943  0.005675  0.011265  0.009796  0.020082
# 2023-01-01   0.013756 -0.003628  0.006080  0.003145  0.014162  0.015273
#
# country        Italy     Japan     Korea  Netherlands  New Zealand    Norway  \
# date
# 1977-01-01       NaN  0.022951       NaN          NaN          NaN       NaN
# 1977-04-01       NaN  0.027244       NaN          NaN          NaN       NaN
# 1977-07-01       NaN  0.003120       NaN          NaN          NaN       NaN
# 1977-10-01       NaN  0.010886       NaN          NaN          NaN       NaN
# 1978-01-01       NaN  0.004615       NaN          NaN          NaN       NaN
# ...              ...       ...       ...          ...          ...       ...
# 2022-01-01  0.030160  0.006876  0.015388     0.029173     0.017820  0.007055
# 2022-04-01  0.018298  0.009756  0.020818     0.024764     0.016643  0.024113
# 2022-07-01  0.021563  0.010628  0.011352     0.040519     0.021527  0.022995
# 2022-10-01  0.043096  0.011252  0.003977     0.013775     0.014335  0.010701
# 2023-01-01  0.003938  0.004500  0.010538    -0.013667     0.012473  0.006886
#
# country     Portugal  South Africa     Spain    Sweden  Switzerland  Türkiye  \
# date
# 1977-01-01       NaN           NaN       NaN       NaN          NaN      NaN
# 1977-04-01       NaN           NaN       NaN       NaN          NaN      NaN
# 1977-07-01       NaN           NaN       NaN       NaN          NaN      NaN
# 1977-10-01       NaN           NaN       NaN       NaN          NaN      NaN
# 1978-01-01       NaN           NaN       NaN       NaN          NaN      NaN
# ...              ...           ...       ...       ...          ...      ...
# 2022-01-01  0.015094      0.014892  0.020852  0.016158     0.007859      NaN
# 2022-04-01  0.050186      0.023478  0.032860  0.032686     0.015595      NaN
# 2022-07-01  0.010619      0.027957  0.012038  0.030796     0.006718      NaN
# 2022-10-01  0.020228      0.008480 -0.001020  0.031062    -0.000791      NaN
# 2023-01-01 -0.002154      0.011202  0.006013  0.014955     0.010084      NaN
#
# country     United Kingdom  United States
# date
# 1977-01-01             NaN       0.017231
# 1977-04-01             NaN       0.022022
# 1977-07-01             NaN       0.014364
# 1977-10-01             NaN       0.010893
# 1978-01-01             NaN       0.017241
# ...                    ...            ...
# 2022-01-01             NaN       0.022835
# 2022-04-01             NaN       0.029738
# 2022-07-01             NaN       0.013147
# 2022-10-01             NaN       0.003669
# 2023-01-01             NaN       0.010452
#
# [185 rows x 20 columns]

# %%
countrylist = ['Japan', 'Canada', 'United States', 'Australia', 'New Zealand',
       'Switzerland', 'Italy', 'France', 'Portugal', 'Spain', 'Sweden',
       'Denmark', 'Germany', 'Netherlands', 'Norway',
       'Belgium', 'Korea', 'South Africa']
df = df[df['country'].isin(countrylist)]

# %%
inflation_df = df.pivot(index='date', columns='country', values='inflation')

# %%
model = VARModel(
    country_column="country",
    date_column="date",
    inflation_column=["inflation"],
    country_exogenous_columns=['gdp_growth', 'interest_rate', 'unemployment_rate'],
    global_exogenous_columns= ['commodity_CRUDE_PETRO', 'commodity_iNATGAS', 'commodity_iAGRICULTURE', 'commodity_iMETMIN', 'commodity_iPRECIOUSMET'],
    lags=[1, 2, 3, 4],
    country_exog_lags=[1],
    global_exog_lags=[1],
    long_format=True
)

# %%
model.fit(df)

# %%
model.predict(df)
# Out:
# /Users/philipphocker/Documents/GitHub/seminar/seminartools/models/var_model.py:239: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   predictions = predictions.stack().reset_index()
#      yearmonth        Country  inflation
# 0   2011-01-01      Australia   0.012578
# 1   2011-01-01        Belgium   0.014346
# 2   2011-01-01         Canada   0.008585
# 3   2011-01-01        Denmark   0.011031
# 4   2011-01-01         France   0.006993
# ..         ...            ...        ...
# 499 2023-04-01   South Africa  -0.001601
# 500 2023-04-01          Spain  -0.059097
# 501 2023-04-01         Sweden  -0.095738
# 502 2023-04-01    Switzerland  -0.014856
# 503 2023-04-01  United States  -0.079564
#
# [504 rows x 3 columns]

# %%
model.models[('inflation', 'United States')].summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                   OLS Regression Results
# ==========================================================================================
# Dep. Variable:     ('inflation', 'United States')   R-squared:                       0.919
# Model:                                        OLS   Adj. R-squared:                  0.702
# Method:                             Least Squares   F-statistic:                     4.235
# Date:                            Wed, 27 Mar 2024   Prob (F-statistic):           5.44e-08
# Time:                                    15:06:52   Log-Likelihood:                 834.85
# No. Observations:                             181   AIC:                            -1406.
# Df Residuals:                                  49   BIC:                            -983.5
# Df Model:                                     131
# Covariance Type:                        nonrobust
# =========================================================================================================
#                                             coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------------------------------
# const                                    -0.0054      0.010     -0.529      0.599      -0.026       0.015
# ('inflation', 'Australia')_lag_1          0.1060      0.117      0.904      0.370      -0.130       0.341
# ('inflation', 'Belgium')_lag_1            1.3920      0.654      2.128      0.038       0.077       2.707
# ('inflation', 'Canada')_lag_1             0.1723      0.153      1.127      0.265      -0.135       0.480
# ('inflation', 'Denmark')_lag_1           -0.1005      0.708     -0.142      0.888      -1.524       1.323
# ('inflation', 'France')_lag_1            -2.9915      1.225     -2.442      0.018      -5.453      -0.530
# ('inflation', 'Germany')_lag_1            1.8938      1.414      1.340      0.187      -0.947       4.735
# ('inflation', 'Italy')_lag_1             -0.8867      1.370     -0.647      0.521      -3.640       1.867
# ('inflation', 'Japan')_lag_1             -0.1511      0.169     -0.896      0.374      -0.490       0.188
# ('inflation', 'Korea')_lag_1             -0.6842      0.409     -1.673      0.101      -1.506       0.138
# ('inflation', 'Netherlands')_lag_1       -0.2016      0.426     -0.474      0.638      -1.057       0.654
# ('inflation', 'New Zealand')_lag_1        0.0985      0.200      0.492      0.625      -0.304       0.501
# ('inflation', 'Norway')_lag_1             0.1393      0.372      0.374      0.710      -0.609       0.888
# ('inflation', 'Portugal')_lag_1           0.1030      0.445      0.231      0.818      -0.792       0.998
# ('inflation', 'South Africa')_lag_1      -1.1649      0.427     -2.730      0.009      -2.022      -0.308
# ('inflation', 'Spain')_lag_1             -0.6297      0.490     -1.286      0.204      -1.614       0.354
# ('inflation', 'Sweden')_lag_1            -0.0177      0.762     -0.023      0.982      -1.549       1.513
# ('inflation', 'Switzerland')_lag_1        0.8267      0.834      0.992      0.326      -0.849       2.502
# ('inflation', 'United States')_lag_1      0.4120      0.184      2.234      0.030       0.041       0.783
# ('inflation', 'Australia')_lag_2          0.1298      0.115      1.125      0.266      -0.102       0.362
# ('inflation', 'Belgium')_lag_2            1.3285      0.843      1.576      0.122      -0.366       3.023
# ('inflation', 'Canada')_lag_2             0.0748      0.151      0.496      0.622      -0.228       0.378
# ('inflation', 'Denmark')_lag_2            1.5087      0.786      1.920      0.061      -0.070       3.088
# ('inflation', 'France')_lag_2            -1.0220      1.734     -0.589      0.558      -4.507       2.463
# ('inflation', 'Germany')_lag_2            0.6998      0.729      0.960      0.342      -0.766       2.165
# ('inflation', 'Italy')_lag_2             -1.0363      2.092     -0.495      0.623      -5.241       3.169
# ('inflation', 'Japan')_lag_2             -0.2259      0.196     -1.155      0.254      -0.619       0.167
# ('inflation', 'Korea')_lag_2             -0.8954      0.677     -1.323      0.192      -2.255       0.464
# ('inflation', 'Netherlands')_lag_2       -0.6974      0.399     -1.746      0.087      -1.500       0.105
# ('inflation', 'New Zealand')_lag_2        0.1896      0.166      1.144      0.258      -0.143       0.523
# ('inflation', 'Norway')_lag_2             0.6452      0.370      1.744      0.087      -0.098       1.389
# ('inflation', 'Portugal')_lag_2           0.1326      0.576      0.230      0.819      -1.024       1.290
# ('inflation', 'South Africa')_lag_2      -0.3409      0.343     -0.995      0.325      -1.029       0.348
# ('inflation', 'Spain')_lag_2              0.9221      0.802      1.149      0.256      -0.690       2.534
# ('inflation', 'Sweden')_lag_2            -2.2444      0.860     -2.610      0.012      -3.972      -0.516
# ('inflation', 'Switzerland')_lag_2       -0.6321      0.937     -0.674      0.503      -2.515       1.251
# ('inflation', 'United States')_lag_2     -0.0186      0.191     -0.097      0.923      -0.403       0.366
# ('inflation', 'Australia')_lag_3          0.0317      0.113      0.280      0.781      -0.196       0.259
# ('inflation', 'Belgium')_lag_3            0.4807      0.694      0.692      0.492      -0.915       1.876
# ('inflation', 'Canada')_lag_3            -0.2361      0.145     -1.623      0.111      -0.528       0.056
# ('inflation', 'Denmark')_lag_3            1.0511      1.004      1.047      0.300      -0.967       3.069
# ('inflation', 'France')_lag_3             0.3075      1.146      0.268      0.790      -1.996       2.611
# ('inflation', 'Germany')_lag_3            0.6804      0.735      0.926      0.359      -0.796       2.157
# ('inflation', 'Italy')_lag_3             -1.0039      1.466     -0.685      0.497      -3.951       1.943
# ('inflation', 'Japan')_lag_3             -0.2571      0.169     -1.526      0.134      -0.596       0.082
# ('inflation', 'Korea')_lag_3             -2.2703      0.848     -2.677      0.010      -3.974      -0.566
# ('inflation', 'Netherlands')_lag_3       -0.1866      0.445     -0.419      0.677      -1.081       0.708
# ('inflation', 'New Zealand')_lag_3        0.0267      0.163      0.164      0.870      -0.301       0.354
# ('inflation', 'Norway')_lag_3            -0.3184      0.236     -1.347      0.184      -0.793       0.156
# ('inflation', 'Portugal')_lag_3          -0.9453      0.829     -1.141      0.260      -2.611       0.720
# ('inflation', 'South Africa')_lag_3      -0.1998      0.451     -0.443      0.659      -1.105       0.706
# ('inflation', 'Spain')_lag_3              0.5299      0.687      0.771      0.444      -0.851       1.911
# ('inflation', 'Sweden')_lag_3             0.8620      0.951      0.906      0.369      -1.049       2.773
# ('inflation', 'Switzerland')_lag_3        0.1297      0.526      0.246      0.806      -0.927       1.187
# ('inflation', 'United States')_lag_3      0.5902      0.207      2.854      0.006       0.175       1.006
# ('inflation', 'Australia')_lag_4          0.0221      0.106      0.208      0.836      -0.192       0.236
# ('inflation', 'Belgium')_lag_4           -0.2002      0.596     -0.336      0.738      -1.397       0.997
# ('inflation', 'Canada')_lag_4             0.3892      0.144      2.703      0.009       0.100       0.679
# ('inflation', 'Denmark')_lag_4            0.4116      0.594      0.693      0.491      -0.782       1.605
# ('inflation', 'France')_lag_4            -1.4750      0.798     -1.848      0.071      -3.079       0.129
# ('inflation', 'Germany')_lag_4            0.4220      0.782      0.539      0.592      -1.150       1.994
# ('inflation', 'Italy')_lag_4             -0.9159      0.912     -1.004      0.320      -2.748       0.917
# ('inflation', 'Japan')_lag_4             -0.0949      0.155     -0.611      0.544      -0.407       0.217
# ('inflation', 'Korea')_lag_4             -0.6765      0.440     -1.539      0.130      -1.560       0.207
# ('inflation', 'Netherlands')_lag_4        1.3846      0.498      2.783      0.008       0.385       2.384
# ('inflation', 'New Zealand')_lag_4        0.0077      0.154      0.050      0.961      -0.302       0.317
# ('inflation', 'Norway')_lag_4            -0.8634      0.480     -1.799      0.078      -1.828       0.101
# ('inflation', 'Portugal')_lag_4          -1.6170      0.652     -2.482      0.017      -2.926      -0.308
# ('inflation', 'South Africa')_lag_4       0.5196      0.403      1.289      0.204      -0.291       1.330
# ('inflation', 'Spain')_lag_4              0.2726      0.480      0.568      0.573      -0.692       1.237
# ('inflation', 'Sweden')_lag_4             1.3098      1.217      1.076      0.287      -1.136       3.755
# ('inflation', 'Switzerland')_lag_4        0.5988      0.646      0.927      0.358      -0.699       1.897
# ('inflation', 'United States')_lag_4     -0.0714      0.164     -0.435      0.666      -0.402       0.259
# gdp_growth_Australia_lag_1                0.0013      0.001      1.762      0.084      -0.000       0.003
# gdp_growth_Belgium_lag_1                 -0.0004      0.006     -0.060      0.953      -0.013       0.012
# gdp_growth_Canada_lag_1                   0.0013      0.001      1.426      0.160      -0.001       0.003
# gdp_growth_Denmark_lag_1                  0.0040      0.003      1.543      0.129      -0.001       0.009
# gdp_growth_France_lag_1                  -0.0038      0.004     -0.876      0.385      -0.013       0.005
# gdp_growth_Germany_lag_1                  0.0052      0.004      1.463      0.150      -0.002       0.012
# gdp_growth_Italy_lag_1                   -0.0005      0.004     -0.108      0.914      -0.009       0.008
# gdp_growth_Japan_lag_1                    0.0005      0.001      0.611      0.544      -0.001       0.002
# gdp_growth_Korea_lag_1                    0.0024      0.002      0.992      0.326      -0.002       0.007
# gdp_growth_Netherlands_lag_1             -0.0092      0.005     -1.993      0.052      -0.019    7.68e-05
# gdp_growth_New Zealand_lag_1             -0.0010      0.001     -1.038      0.304      -0.003       0.001
# gdp_growth_Norway_lag_1                   0.0010      0.002      0.487      0.628      -0.003       0.005
# gdp_growth_Portugal_lag_1                -0.0038      0.003     -1.119      0.269      -0.011       0.003
# gdp_growth_South Africa_lag_1            -0.0021      0.002     -0.964      0.340      -0.006       0.002
# gdp_growth_Spain_lag_1                    0.0160      0.007      2.175      0.035       0.001       0.031
# gdp_growth_Sweden_lag_1                  -0.0111      0.004     -3.006      0.004      -0.018      -0.004
# gdp_growth_Switzerland_lag_1              0.0008      0.006      0.133      0.895      -0.012       0.013
# gdp_growth_United States_lag_1            0.0016      0.001      1.560      0.125      -0.000       0.004
# interest_rate_Australia_lag_1            -0.0005      0.000     -1.559      0.125      -0.001       0.000
# interest_rate_Belgium_lag_1              -0.0389      0.014     -2.724      0.009      -0.068      -0.010
# interest_rate_Canada_lag_1               -0.0001      0.001     -0.170      0.866      -0.002       0.001
# interest_rate_Denmark_lag_1               0.0133      0.014      0.976      0.334      -0.014       0.041
# interest_rate_France_lag_1               -0.0222      0.007     -3.144      0.003      -0.036      -0.008
# interest_rate_Germany_lag_1              -0.0030      0.007     -0.454      0.652      -0.016       0.010
# interest_rate_Italy_lag_1                -0.0341      0.041     -0.823      0.415      -0.117       0.049
# interest_rate_Japan_lag_1                 0.0021      0.001      1.843      0.071      -0.000       0.004
# interest_rate_Korea_lag_1                 0.0045      0.006      0.717      0.477      -0.008       0.017
# interest_rate_Netherlands_lag_1           0.0257      0.020      1.257      0.215      -0.015       0.067
# interest_rate_New Zealand_lag_1          -0.0006      0.000     -1.912      0.062      -0.001    3.22e-05
# interest_rate_Norway_lag_1               -0.0095      0.007     -1.373      0.176      -0.023       0.004
# interest_rate_Portugal_lag_1              0.0301      0.040      0.759      0.452      -0.050       0.110
# interest_rate_South Africa_lag_1          0.0020      0.002      1.291      0.203      -0.001       0.005
# interest_rate_Spain_lag_1                 0.0159      0.066      0.240      0.812      -0.117       0.149
# interest_rate_Sweden_lag_1                0.0266      0.007      3.727      0.001       0.012       0.041
# interest_rate_Switzerland_lag_1          -0.0118      0.004     -3.165      0.003      -0.019      -0.004
# interest_rate_United States_lag_1        -0.0004      0.001     -0.633      0.530      -0.002       0.001
# unemployment_rate_Australia_lag_1        -0.0011      0.001     -1.290      0.203      -0.003       0.001
# unemployment_rate_Belgium_lag_1           0.0022      0.004      0.612      0.544      -0.005       0.009
# unemployment_rate_Canada_lag_1            0.0007      0.001      0.549      0.585      -0.002       0.003
# unemployment_rate_Denmark_lag_1           0.0081      0.006      1.442      0.156      -0.003       0.019
# unemployment_rate_France_lag_1            0.0085      0.003      3.154      0.003       0.003       0.014
# unemployment_rate_Germany_lag_1          -0.0007      0.002     -0.424      0.673      -0.004       0.003
# unemployment_rate_Italy_lag_1            -0.0050      0.003     -1.710      0.094      -0.011       0.001
# unemployment_rate_Japan_lag_1             0.0047      0.002      2.286      0.027       0.001       0.009
# unemployment_rate_Korea_lag_1            -0.0021      0.005     -0.386      0.701      -0.013       0.009
# unemployment_rate_Netherlands_lag_1       0.0039      0.006      0.620      0.538      -0.009       0.017
# unemployment_rate_New Zealand_lag_1       0.0009      0.001      1.676      0.100      -0.000       0.002
# unemployment_rate_Norway_lag_1           -0.0049      0.007     -0.661      0.512      -0.020       0.010
# unemployment_rate_Portugal_lag_1         -0.0053      0.004     -1.355      0.181      -0.013       0.003
# unemployment_rate_South Africa_lag_1     -0.0002      0.001     -0.373      0.711      -0.001       0.001
# unemployment_rate_Spain_lag_1             0.0009      0.002      0.376      0.709      -0.004       0.006
# unemployment_rate_Sweden_lag_1           -0.0048      0.003     -1.635      0.109      -0.011       0.001
# unemployment_rate_Switzerland_lag_1       0.0031      0.001      2.105      0.040       0.000       0.006
# unemployment_rate_United States_lag_1    -0.0018      0.002     -1.165      0.249      -0.005       0.001
# commodity_CRUDE_PETRO_lag_1               0.0089      0.003      2.543      0.014       0.002       0.016
# commodity_iNATGAS_lag_1                   0.0050      0.004      1.220      0.228      -0.003       0.013
# commodity_iAGRICULTURE_lag_1             -0.0084      0.015     -0.568      0.573      -0.038       0.021
# commodity_iMETMIN_lag_1                  -0.0034      0.009     -0.392      0.697      -0.021       0.014
# commodity_iPRECIOUSMET_lag_1             -0.0005      0.008     -0.061      0.951      -0.016       0.015
# ==============================================================================
# Omnibus:                       15.713   Durbin-Watson:                   2.198
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               34.930
# Skew:                          -0.342   Prob(JB):                     2.60e-08
# Kurtosis:                       5.041   Cond. No.                     3.37e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.37e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
