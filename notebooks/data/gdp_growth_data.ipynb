# %% [markdown]
# # GDP Growth Data

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Read Data

# %%
# Data on GDP growth
df_gdp = pd.read_excel(
    "./../../assets/GDP-growth.xlsx",
    sheet_name="Quarterly real GDP growth",
    header=5,
    skipfooter=5
)
df_gdp.set_index('Period', inplace=True, drop=True)
df_gdp.drop(columns=['Unnamed: 1', 'Unnamed: 2'], inplace=True)

# %%
df_gdp
# Out:
#                                                  Q2-1947 Unnamed: 4  Q3-1947  \
# Period
# Country                                              NaN        NaN      NaN
# Australia                                            NaN         ..      NaN
# Austria                                              NaN         ..      NaN
# Belgium                                              NaN         ..      NaN
# Canada                                               NaN         ..      NaN
# Chile                                                NaN         ..      NaN
# Colombia                                             NaN         ..      NaN
# Costa Rica                                           NaN         ..      NaN
# Czechia                                              NaN         ..      NaN
# Denmark                                              NaN         ..      NaN
# Estonia                                              NaN         ..      NaN
# Finland                                              NaN         ..      NaN
# France                                               NaN         ..      NaN
# Germany                                              NaN         ..      NaN
# Greece                                               NaN         ..      NaN
# Hungary                                              NaN         ..      NaN
# Iceland                                              NaN         ..      NaN
# Ireland                                              NaN         ..      NaN
# Israel                                               NaN         ..      NaN
# Italy                                                NaN         ..      NaN
# Japan                                                NaN         ..      NaN
# Korea                                                NaN         ..      NaN
# Latvia                                               NaN         ..      NaN
# Lithuania                                            NaN         ..      NaN
# Luxembourg                                           NaN         ..      NaN
# Mexico                                               NaN         ..      NaN
# Netherlands                                          NaN         ..      NaN
# New Zealand                                          NaN         ..      NaN
# Norway                                               NaN         ..      NaN
# Poland                                               NaN         ..      NaN
# Portugal                                             NaN         ..      NaN
# Slovak Republic                                      NaN         ..      NaN
# Slovenia                                             NaN         ..      NaN
# Spain                                                NaN         ..      NaN
# Sweden                                               NaN         ..      NaN
# Switzerland                                          NaN         ..      NaN
# Türkiye                                              NaN         ..      NaN
# United Kingdom                                       NaN         ..      NaN
# United States                                        NaN  -0.265224      NaN
# European Union – 27 countries (from 01/02/2020)      NaN         ..      NaN
# Euro area (20 countries)                             NaN         ..      NaN
# G7                                                   NaN         ..      NaN
# NAFTA                                                NaN         ..      NaN
# OECD - Europe                                        NaN         ..      NaN
# G20                                                  NaN         ..      NaN
# OECD - Total                                         NaN         ..      NaN
# Argentina                                            NaN         ..      NaN
# Brazil                                               NaN         ..      NaN
# Bulgaria                                             NaN         ..      NaN
# China (People's Republic of)                         NaN         ..      NaN
# Croatia                                              NaN         ..      NaN
# India                                                NaN         ..      NaN
# Indonesia                                            NaN         ..      NaN
# Romania                                              NaN         ..      NaN
# Russia                                               NaN         ..      NaN
# Saudi Arabia                                         NaN         ..      NaN
# South Africa                                         NaN         ..      NaN
#
#                                                 Unnamed: 6  Q4-1947  \
# Period
# Country                                                NaN      NaN
# Australia                                               ..      NaN
# Austria                                                 ..      NaN
# Belgium                                                 ..      NaN
# Canada                                                  ..      NaN
# Chile                                                   ..      NaN
# Colombia                                                ..      NaN
# Costa Rica                                              ..      NaN
# Czechia                                                 ..      NaN
# Denmark                                                 ..      NaN
# Estonia                                                 ..      NaN
# Finland                                                 ..      NaN
# France                                                  ..      NaN
# Germany                                                 ..      NaN
# Greece                                                  ..      NaN
# Hungary                                                 ..      NaN
# Iceland                                                 ..      NaN
# Ireland                                                 ..      NaN
# Israel                                                  ..      NaN
# Italy                                                   ..      NaN
# Japan                                                   ..      NaN
# Korea                                                   ..      NaN
# Latvia                                                  ..      NaN
# Lithuania                                               ..      NaN
# Luxembourg                                              ..      NaN
# Mexico                                                  ..      NaN
# Netherlands                                             ..      NaN
# New Zealand                                             ..      NaN
# Norway                                                  ..      NaN
# Poland                                                  ..      NaN
# Portugal                                                ..      NaN
# Slovak Republic                                         ..      NaN
# Slovenia                                                ..      NaN
# Spain                                                   ..      NaN
# Sweden                                                  ..      NaN
# Switzerland                                             ..      NaN
# Türkiye                                                 ..      NaN
# United Kingdom                                          ..      NaN
# United States                                    -0.204879      NaN
# European Union – 27 countries (from 01/02/2020)         ..      NaN
# Euro area (20 countries)                                ..      NaN
# G7                                                      ..      NaN
# NAFTA                                                   ..      NaN
# OECD - Europe                                           ..      NaN
# G20                                                     ..      NaN
# OECD - Total                                            ..      NaN
# Argentina                                               ..      NaN
# Brazil                                                  ..      NaN
# Bulgaria                                                ..      NaN
# China (People's Republic of)                            ..      NaN
# Croatia                                                 ..      NaN
# India                                                   ..      NaN
# Indonesia                                               ..      NaN
# Romania                                                 ..      NaN
# Russia                                                  ..      NaN
# Saudi Arabia                                            ..      NaN
# South Africa                                            ..      NaN
#
#                                                 Unnamed: 8  Q1-1948  \
# Period
# Country                                                NaN      NaN
# Australia                                               ..      NaN
# Austria                                                 ..      NaN
# Belgium                                                 ..      NaN
# Canada                                                  ..      NaN
# Chile                                                   ..      NaN
# Colombia                                                ..      NaN
# Costa Rica                                              ..      NaN
# Czechia                                                 ..      NaN
# Denmark                                                 ..      NaN
# Estonia                                                 ..      NaN
# Finland                                                 ..      NaN
# France                                                  ..      NaN
# Germany                                                 ..      NaN
# Greece                                                  ..      NaN
# Hungary                                                 ..      NaN
# Iceland                                                 ..      NaN
# Ireland                                                 ..      NaN
# Israel                                                  ..      NaN
# Italy                                                   ..      NaN
# Japan                                                   ..      NaN
# Korea                                                   ..      NaN
# Latvia                                                  ..      NaN
# Lithuania                                               ..      NaN
# Luxembourg                                              ..      NaN
# Mexico                                                  ..      NaN
# Netherlands                                             ..      NaN
# New Zealand                                             ..      NaN
# Norway                                                  ..      NaN
# Poland                                                  ..      NaN
# Portugal                                                ..      NaN
# Slovak Republic                                         ..      NaN
# Slovenia                                                ..      NaN
# Spain                                                   ..      NaN
# Sweden                                                  ..      NaN
# Switzerland                                             ..      NaN
# Türkiye                                                 ..      NaN
# United Kingdom                                          ..      NaN
# United States                                     1.565987      NaN
# European Union – 27 countries (from 01/02/2020)         ..      NaN
# Euro area (20 countries)                                ..      NaN
# G7                                                      ..      NaN
# NAFTA                                                   ..      NaN
# OECD - Europe                                           ..      NaN
# G20                                                     ..      NaN
# OECD - Total                                            ..      NaN
# Argentina                                               ..      NaN
# Brazil                                                  ..      NaN
# Bulgaria                                                ..      NaN
# China (People's Republic of)                            ..      NaN
# Croatia                                                 ..      NaN
# India                                                   ..      NaN
# Indonesia                                               ..      NaN
# Romania                                                 ..      NaN
# Russia                                                  ..      NaN
# Saudi Arabia                                            ..      NaN
# South Africa                                            ..      NaN
#
#                                                 Unnamed: 10  Q2-1948  \
# Period
# Country                                                 NaN      NaN
# Australia                                                ..      NaN
# Austria                                                  ..      NaN
# Belgium                                                  ..      NaN
# Canada                                                   ..      NaN
# Chile                                                    ..      NaN
# Colombia                                                 ..      NaN
# Costa Rica                                               ..      NaN
# Czechia                                                  ..      NaN
# Denmark                                                  ..      NaN
# Estonia                                                  ..      NaN
# Finland                                                  ..      NaN
# France                                                   ..      NaN
# Germany                                                  ..      NaN
# Greece                                                   ..      NaN
# Hungary                                                  ..      NaN
# Iceland                                                  ..      NaN
# Ireland                                                  ..      NaN
# Israel                                                   ..      NaN
# Italy                                                    ..      NaN
# Japan                                                    ..      NaN
# Korea                                                    ..      NaN
# Latvia                                                   ..      NaN
# Lithuania                                                ..      NaN
# Luxembourg                                               ..      NaN
# Mexico                                                   ..      NaN
# Netherlands                                              ..      NaN
# New Zealand                                              ..      NaN
# Norway                                                   ..      NaN
# Poland                                                   ..      NaN
# Portugal                                                 ..      NaN
# Slovak Republic                                          ..      NaN
# Slovenia                                                 ..      NaN
# Spain                                                    ..      NaN
# Sweden                                                   ..      NaN
# Switzerland                                              ..      NaN
# Türkiye                                                  ..      NaN
# United Kingdom                                           ..      NaN
# United States                                      1.506038      NaN
# European Union – 27 countries (from 01/02/2020)          ..      NaN
# Euro area (20 countries)                                 ..      NaN
# G7                                                       ..      NaN
# NAFTA                                                    ..      NaN
# OECD - Europe                                            ..      NaN
# G20                                                      ..      NaN
# OECD - Total                                             ..      NaN
# Argentina                                                ..      NaN
# Brazil                                                   ..      NaN
# Bulgaria                                                 ..      NaN
# China (People's Republic of)                             ..      NaN
# Croatia                                                  ..      NaN
# India                                                    ..      NaN
# Indonesia                                                ..      NaN
# Romania                                                  ..      NaN
# Russia                                                   ..      NaN
# Saudi Arabia                                             ..      NaN
# South Africa                                             ..      NaN
#
#                                                 Unnamed: 12  ...  Q4-2022  \
# Period                                                       ...
# Country                                                 NaN  ...      NaN
# Australia                                                ..  ...      NaN
# Austria                                                  ..  ...      NaN
# Belgium                                                  ..  ...      (P)
# Canada                                                   ..  ...      NaN
# Chile                                                    ..  ...      NaN
# Colombia                                                 ..  ...      NaN
# Costa Rica                                               ..  ...      NaN
# Czechia                                                  ..  ...      NaN
# Denmark                                                  ..  ...      NaN
# Estonia                                                  ..  ...      NaN
# Finland                                                  ..  ...      NaN
# France                                                   ..  ...      NaN
# Germany                                                  ..  ...      (P)
# Greece                                                   ..  ...      (P)
# Hungary                                                  ..  ...      (P)
# Iceland                                                  ..  ...      NaN
# Ireland                                                  ..  ...      NaN
# Israel                                                   ..  ...      NaN
# Italy                                                    ..  ...      NaN
# Japan                                                    ..  ...      NaN
# Korea                                                    ..  ...      (P)
# Latvia                                                   ..  ...      NaN
# Lithuania                                                ..  ...      NaN
# Luxembourg                                               ..  ...      NaN
# Mexico                                                   ..  ...      (P)
# Netherlands                                              ..  ...      (P)
# New Zealand                                              ..  ...      NaN
# Norway                                                   ..  ...      NaN
# Poland                                                   ..  ...      NaN
# Portugal                                                 ..  ...      (P)
# Slovak Republic                                          ..  ...      NaN
# Slovenia                                                 ..  ...      NaN
# Spain                                                    ..  ...      (P)
# Sweden                                                   ..  ...      NaN
# Switzerland                                              ..  ...      NaN
# Türkiye                                                  ..  ...      NaN
# United Kingdom                                           ..  ...      NaN
# United States                                      1.652377  ...      NaN
# European Union – 27 countries (from 01/02/2020)          ..  ...      NaN
# Euro area (20 countries)                                 ..  ...      NaN
# G7                                                       ..  ...      NaN
# NAFTA                                                    ..  ...      NaN
# OECD - Europe                                            ..  ...      NaN
# G20                                                      ..  ...      NaN
# OECD - Total                                             ..  ...      NaN
# Argentina                                                ..  ...      NaN
# Brazil                                                   ..  ...      NaN
# Bulgaria                                                 ..  ...      NaN
# China (People's Republic of)                             ..  ...      NaN
# Croatia                                                  ..  ...      (P)
# India                                                    ..  ...      NaN
# Indonesia                                                ..  ...      NaN
# Romania                                                  ..  ...      (P)
# Russia                                                   ..  ...      NaN
# Saudi Arabia                                             ..  ...      NaN
# South Africa                                             ..  ...      NaN
#
#                                                 Unnamed: 608  Q1-2023  \
# Period
# Country                                                  NaN      NaN
# Australia                                           0.854933      NaN
# Austria                                            -0.109469      NaN
# Belgium                                             0.242596      (P)
# Canada                                             -0.215348      NaN
# Chile                                               0.134982      NaN
# Colombia                                           -1.636127      NaN
# Costa Rica                                          2.252222      NaN
# Czechia                                            -0.355478      NaN
# Denmark                                             0.129033      NaN
# Estonia                                            -1.436173      NaN
# Finland                                            -0.546467      NaN
# France                                             -0.049267      NaN
# Germany                                            -0.406273      (P)
# Greece                                              0.914762      (P)
# Hungary                                            -0.836046      (P)
# Iceland                                             2.697238      NaN
# Ireland                                             -1.57888      NaN
# Israel                                              1.071183      NaN
# Italy                                              -0.244622      NaN
# Japan                                               0.248075      NaN
# Korea                                              -0.302968      (P)
# Latvia                                              0.639816      NaN
# Lithuania                                          -0.452052      NaN
# Luxembourg                                         -2.315866      (P)
# Mexico                                               0.67767      (P)
# Netherlands                                         0.686291      (P)
# New Zealand                                        -0.608212      NaN
# Norway                                             -0.669143      NaN
# Poland                                             -2.276955      NaN
# Portugal                                            0.508484      (P)
# Slovak Republic                                     0.234272      NaN
# Slovenia                                            0.608575      NaN
# Spain                                               0.491224      (P)
# Sweden                                             -1.255332      NaN
# Switzerland                                        -0.026666      NaN
# Türkiye                                             1.148543      NaN
# United Kingdom                                      0.103799      NaN
# United States                                       0.635422      NaN
# European Union – 27 countries (from 01/02/2020)    -0.189358      NaN
# Euro area (20 countries)                           -0.089443      NaN
# G7                                                  0.283549      NaN
# NAFTA                                               0.574439      NaN
# OECD - Europe                                      -0.115208      NaN
# G20                                                  0.51121      NaN
# OECD - Total                                        0.196813      NaN
# Argentina                                          -1.691146      NaN
# Brazil                                             -0.116739      NaN
# Bulgaria                                            0.585075      (P)
# China (People's Republic of)                             0.6      NaN
# Croatia                                             0.283145      (P)
# India                                                1.14099      NaN
# Indonesia                                           2.336994      NaN
# Romania                                             1.223659      (P)
# Russia                                                    ..      NaN
# Saudi Arabia                                        1.164417      NaN
# South Africa                                       -1.094064      NaN
#
#                                                 Unnamed: 610  Q2-2023  \
# Period
# Country                                                  NaN      NaN
# Australia                                           0.533364      NaN
# Austria                                             0.091308      NaN
# Belgium                                             0.413039      (P)
# Canada                                              0.610026      NaN
# Chile                                               0.546959      NaN
# Colombia                                            2.171743      NaN
# Costa Rica                                         -0.584824      NaN
# Czechia                                               0.1135      NaN
# Denmark                                             0.906018      NaN
# Estonia                                            -0.777569      NaN
# Finland                                               0.0291      NaN
# France                                              0.046662      NaN
# Germany                                             0.104301      (P)
# Greece                                              0.050314      (P)
# Hungary                                            -0.245233      (P)
# Iceland                                             1.257496      NaN
# Ireland                                            -1.878235      NaN
# Israel                                              0.753983      NaN
# Italy                                               0.552944      NaN
# Japan                                               1.227393      NaN
# Korea                                               0.329875      (P)
# Latvia                                             -0.471046      NaN
# Lithuania                                          -1.855371      NaN
# Luxembourg                                          0.852669      (P)
# Mexico                                               0.57031      (P)
# Netherlands                                        -0.494664      (P)
# New Zealand                                        -0.226055      NaN
# Norway                                              0.214575      NaN
# Poland                                              1.101976      NaN
# Portugal                                            1.460956      (P)
# Slovak Republic                                     0.197017      NaN
# Slovenia                                            0.157376      NaN
# Spain                                               0.504719      (P)
# Sweden                                              0.656897      NaN
# Switzerland                                         0.309543      NaN
# Türkiye                                            -0.252098      NaN
# United Kingdom                                      0.253154      NaN
# United States                                       0.556381      NaN
# European Union – 27 countries (from 01/02/2020)     0.149683      NaN
# Euro area (20 countries)                            0.093795      NaN
# G7                                                  0.526785      NaN
# NAFTA                                               0.562402      NaN
# OECD - Europe                                       0.192864      NaN
# G20                                                  1.03641      NaN
# OECD - Total                                        0.464918      NaN
# Argentina                                           0.809387      NaN
# Brazil                                              1.439727      NaN
# Bulgaria                                            0.349776      (P)
# China (People's Republic of)                             2.1      NaN
# Croatia                                             0.881596      (P)
# India                                                2.08053      NaN
# Indonesia                                           0.837339      NaN
# Romania                                            -0.804894      (P)
# Russia                                                    ..      NaN
# Saudi Arabia                                       -1.116411      NaN
# South Africa                                        0.406619      NaN
#
#                                                 Unnamed: 612  Q3-2023  \
# Period
# Country                                                  NaN      NaN
# Australia                                           0.438743      NaN
# Austria                                            -1.109172      NaN
# Belgium                                              0.33299      (P)
# Canada                                              0.338964      NaN
# Chile                                              -0.348738      NaN
# Colombia                                           -0.988247      NaN
# Costa Rica                                          2.504614      NaN
# Czechia                                              0.08016      NaN
# Denmark                                            -0.699459      NaN
# Estonia                                            -0.600577      NaN
# Finland                                             0.345671      NaN
# France                                              0.658526      NaN
# Germany                                             0.027781      (P)
# Greece                                              1.102534      (P)
# Hungary                                            -0.029911      (P)
# Iceland                                             1.599448      NaN
# Ireland                                            -0.364486      NaN
# Israel                                              0.787807      NaN
# Italy                                              -0.345906      NaN
# Japan                                               0.880415      NaN
# Korea                                               0.608653      (P)
# Latvia                                             -0.303692      NaN
# Lithuania                                           2.447931      NaN
# Luxembourg                                         -0.185092      (P)
# Mexico                                              0.934633      (P)
# Netherlands                                        -0.444697      (P)
# New Zealand                                         0.484883      NaN
# Norway                                             -0.513449      NaN
# Poland                                              0.295509      NaN
# Portugal                                            0.129863      (P)
# Slovak Republic                                     0.437188      NaN
# Slovenia                                            0.993703      NaN
# Spain                                               0.503503      (P)
# Sweden                                              -0.62914      NaN
# Switzerland                                        -0.127097      NaN
# Türkiye                                             3.306434      NaN
# United Kingdom                                      0.037754      NaN
# United States                                       0.511122      NaN
# European Union – 27 countries (from 01/02/2020)     0.110064      NaN
# Euro area (20 countries)                            0.132621      NaN
# G7                                                  0.413961      NaN
# NAFTA                                               0.539399      NaN
# OECD - Europe                                       0.393359      NaN
# G20                                                  0.61984      NaN
# OECD - Total                                        0.481067      NaN
# Argentina                                          -2.727763      NaN
# Brazil                                              0.984869      NaN
# Bulgaria                                            0.412767      (P)
# China (People's Republic of)                             0.6      NaN
# Croatia                                             1.490864      (P)
# India                                                 1.8875      NaN
# Indonesia                                           0.866408      NaN
# Romania                                             1.548405      (P)
# Russia                                                    ..      NaN
# Saudi Arabia                                       -0.505205      NaN
# South Africa                                        0.457335      NaN
#
#                                                 Unnamed: 614  Q4-2023  \
# Period
# Country                                                  NaN      NaN
# Australia                                            0.21198      NaN
# Austria                                            -0.518956      NaN
# Belgium                                             0.381116      NaN
# Canada                                              -0.26663      (P)
# Chile                                               0.331248      NaN
# Colombia                                             0.23878      NaN
# Costa Rica                                          1.286147      NaN
# Czechia                                            -0.631639      (P)
# Denmark                                            -0.652085      NaN
# Estonia                                            -1.293712      NaN
# Finland                                            -0.856086      NaN
# France                                              -0.02956      NaN
# Germany                                            -0.009261      (E)
# Greece                                              0.015551      NaN
# Hungary                                             0.855191      NaN
# Iceland                                            -3.753649      NaN
# Ireland                                            -1.911117      (E)
# Israel                                              0.659552      NaN
# Italy                                               0.103646      NaN
# Japan                                               -0.72869      NaN
# Korea                                               0.616073      (P)
# Latvia                                               0.17423      NaN
# Lithuania                                           0.041464      NaN
# Luxembourg                                         -0.143497      NaN
# Mexico                                              0.746189      NaN
# Netherlands                                         -0.30796      NaN
# New Zealand                                        -0.254197      NaN
# Norway                                             -0.523177      NaN
# Poland                                              1.488774      NaN
# Portugal                                           -0.211217      NaN
# Slovak Republic                                     0.246499      NaN
# Slovenia                                           -0.157114      NaN
# Spain                                               0.394096      (P)
# Sweden                                             -0.094538      NaN
# Switzerland                                         0.270626      NaN
# Türkiye                                              0.27253      NaN
# United Kingdom                                     -0.128843      NaN
# United States                                       1.193871      NaN
# European Union – 27 countries (from 01/02/2020)    -0.053278      NaN
# Euro area (20 countries)                            -0.12318      NaN
# G7                                                  0.504435      NaN
# NAFTA                                               1.037427      NaN
# OECD - Europe                                       0.039922      NaN
# G20                                                      0.7      NaN
# OECD - Total                                        0.418728      NaN
# Argentina                                           2.723687      NaN
# Brazil                                              0.144535      NaN
# Bulgaria                                            0.396863      NaN
# China (People's Republic of)                             1.5      NaN
# Croatia                                              0.28588      NaN
# India                                                1.73614      NaN
# Indonesia                                            0.80923      NaN
# Romania                                             0.887211      NaN
# Russia                                                    ..      NaN
# Saudi Arabia                                       -3.176124      NaN
# South Africa                                       -0.247545      NaN
#
#                                                 Unnamed: 616
# Period
# Country                                                  NaN
# Australia                                                 ..
# Austria                                             0.230333
# Belgium                                             0.420257
# Canada                                                   0.3
# Chile                                                     ..
# Colombia                                                  ..
# Costa Rica                                          1.781322
# Czechia                                             0.232706
# Denmark                                                   ..
# Estonia                                            -0.365528
# Finland                                                   ..
# France                                             -0.018617
# Germany                                            -0.287057
# Greece                                                    ..
# Hungary                                                   ..
# Iceland                                                   ..
# Ireland                                            -0.724847
# Israel                                                    ..
# Italy                                               0.186563
# Japan                                                     ..
# Korea                                                0.63093
# Latvia                                               0.42992
# Lithuania                                          -0.291716
# Luxembourg                                                ..
# Mexico                                                   0.1
# Netherlands                                               ..
# New Zealand                                               ..
# Norway                                                    ..
# Poland                                                    ..
# Portugal                                            0.811378
# Slovak Republic                                           ..
# Slovenia                                                  ..
# Spain                                               0.623114
# Sweden                                              0.094446
# Switzerland                                               ..
# Türkiye                                                   ..
# United Kingdom                                            ..
# United States                                       0.809966
# European Union – 27 countries (from 01/02/2020)     0.006341
# Euro area (20 countries)                            0.030543
# G7                                                        ..
# NAFTA                                               0.701521
# OECD - Europe                                             ..
# G20                                                       ..
# OECD - Total                                              ..
# Argentina                                                 ..
# Brazil                                                    ..
# Bulgaria                                                  ..
# China (People's Republic of)                               1
# Croatia                                                   ..
# India                                                     ..
# Indonesia                                                 ..
# Romania                                                   ..
# Russia                                                    ..
# Saudi Arabia                                             0.4
# South Africa                                              ..
#
# [57 rows x 614 columns]

# %%
# rename columns
for i in range(int(len(df_gdp.columns) / 2)):
    df_gdp.rename(
        columns={
            df_gdp.columns[2*i+1]: df_gdp.columns[2*i]
        },
        inplace=True
    )

# %%
df_gdp = df_gdp.T
df_gdp.drop(columns=['Country'], inplace=True)

# %%
# Coerce non-numeric values to NaN
df_gdp = df_gdp.apply(pd.to_numeric, errors='coerce')

# %%
# Delete rows that are all NaN
df_gdp.dropna(how='all', inplace=True)

# %%
df_gdp
# Out:
# Period   Australia   Austria   Belgium    Canada     Chile  Colombia  \
# Q2-1947        NaN       NaN       NaN       NaN       NaN       NaN
# Q3-1947        NaN       NaN       NaN       NaN       NaN       NaN
# Q4-1947        NaN       NaN       NaN       NaN       NaN       NaN
# Q1-1948        NaN       NaN       NaN       NaN       NaN       NaN
# Q2-1948        NaN       NaN       NaN       NaN       NaN       NaN
# ...            ...       ...       ...       ...       ...       ...
# Q4-2022   0.854933 -0.109469  0.242596 -0.215348  0.134982 -1.636127
# Q1-2023   0.533364  0.091308  0.413039  0.610026  0.546959  2.171743
# Q2-2023   0.438743 -1.109172  0.332990  0.338964 -0.348738 -0.988247
# Q3-2023   0.211980 -0.518956  0.381116 -0.266630  0.331248  0.238780
# Q4-2023        NaN  0.230333  0.420257  0.300000       NaN       NaN
#
# Period   Costa Rica   Czechia   Denmark   Estonia  ...    Brazil  Bulgaria  \
# Q2-1947         NaN       NaN       NaN       NaN  ...       NaN       NaN
# Q3-1947         NaN       NaN       NaN       NaN  ...       NaN       NaN
# Q4-1947         NaN       NaN       NaN       NaN  ...       NaN       NaN
# Q1-1948         NaN       NaN       NaN       NaN  ...       NaN       NaN
# Q2-1948         NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...             ...       ...       ...       ...  ...       ...       ...
# Q4-2022    2.252222 -0.355478  0.129033 -1.436173  ... -0.116739  0.585075
# Q1-2023   -0.584824  0.113500  0.906018 -0.777569  ...  1.439727  0.349776
# Q2-2023    2.504614  0.080160 -0.699459 -0.600577  ...  0.984869  0.412767
# Q3-2023    1.286147 -0.631639 -0.652085 -1.293712  ...  0.144535  0.396863
# Q4-2023    1.781322  0.232706       NaN -0.365528  ...       NaN       NaN
#
# Period   China (People's Republic of)   Croatia    India  Indonesia   Romania  \
# Q2-1947                           NaN       NaN      NaN        NaN       NaN
# Q3-1947                           NaN       NaN      NaN        NaN       NaN
# Q4-1947                           NaN       NaN      NaN        NaN       NaN
# Q1-1948                           NaN       NaN      NaN        NaN       NaN
# Q2-1948                           NaN       NaN      NaN        NaN       NaN
# ...                               ...       ...      ...        ...       ...
# Q4-2022                           0.6  0.283145  1.14099   2.336994  1.223659
# Q1-2023                           2.1  0.881596  2.08053   0.837339 -0.804894
# Q2-2023                           0.6  1.490864  1.88750   0.866408  1.548405
# Q3-2023                           1.5  0.285880  1.73614   0.809230  0.887211
# Q4-2023                           1.0       NaN      NaN        NaN       NaN
#
# Period   Russia  Saudi Arabia  South Africa
# Q2-1947     NaN           NaN           NaN
# Q3-1947     NaN           NaN           NaN
# Q4-1947     NaN           NaN           NaN
# Q1-1948     NaN           NaN           NaN
# Q2-1948     NaN           NaN           NaN
# ...         ...           ...           ...
# Q4-2022     NaN      1.164417     -1.094064
# Q1-2023     NaN     -1.116411      0.406619
# Q2-2023     NaN     -0.505205      0.457335
# Q3-2023     NaN     -3.176124     -0.247545
# Q4-2023     NaN      0.400000           NaN
#
# [307 rows x 56 columns]

# %%
# Change the index to datetime
def parse_quarter_string(q_string):
    # Split the string into its components (e.g., "Q2-1947" -> ["Q2", "1947"])
    quarter_part, year_part = q_string.split('-')
    
    # Extract the quarter number
    quarter_number = int(quarter_part[1])  # Convert "2" to 2
    
    # Determine the month that corresponds to the quarter
    month = (quarter_number - 1) * 3 + 1  # Quarter 1 starts in January, Quarter 2 in April, etc.
    
    # Create a datetime object for the first day of the starting month of the quarter
    return pd.Timestamp(year=int(year_part), month=month, day=1)

# Apply the function to the index
df_gdp.index = df_gdp.index.map(parse_quarter_string)

# %%
df_gdp
# Out:
# Period      Australia   Austria   Belgium    Canada     Chile  Colombia  \
# 1947-04-01        NaN       NaN       NaN       NaN       NaN       NaN
# 1947-07-01        NaN       NaN       NaN       NaN       NaN       NaN
# 1947-10-01        NaN       NaN       NaN       NaN       NaN       NaN
# 1948-01-01        NaN       NaN       NaN       NaN       NaN       NaN
# 1948-04-01        NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# 2022-10-01   0.854933 -0.109469  0.242596 -0.215348  0.134982 -1.636127
# 2023-01-01   0.533364  0.091308  0.413039  0.610026  0.546959  2.171743
# 2023-04-01   0.438743 -1.109172  0.332990  0.338964 -0.348738 -0.988247
# 2023-07-01   0.211980 -0.518956  0.381116 -0.266630  0.331248  0.238780
# 2023-10-01        NaN  0.230333  0.420257  0.300000       NaN       NaN
#
# Period      Costa Rica   Czechia   Denmark   Estonia  ...    Brazil  Bulgaria  \
# 1947-04-01         NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1947-07-01         NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1947-10-01         NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1948-01-01         NaN       NaN       NaN       NaN  ...       NaN       NaN
# 1948-04-01         NaN       NaN       NaN       NaN  ...       NaN       NaN
# ...                ...       ...       ...       ...  ...       ...       ...
# 2022-10-01    2.252222 -0.355478  0.129033 -1.436173  ... -0.116739  0.585075
# 2023-01-01   -0.584824  0.113500  0.906018 -0.777569  ...  1.439727  0.349776
# 2023-04-01    2.504614  0.080160 -0.699459 -0.600577  ...  0.984869  0.412767
# 2023-07-01    1.286147 -0.631639 -0.652085 -1.293712  ...  0.144535  0.396863
# 2023-10-01    1.781322  0.232706       NaN -0.365528  ...       NaN       NaN
#
# Period      China (People's Republic of)   Croatia    India  Indonesia  \
# 1947-04-01                           NaN       NaN      NaN        NaN
# 1947-07-01                           NaN       NaN      NaN        NaN
# 1947-10-01                           NaN       NaN      NaN        NaN
# 1948-01-01                           NaN       NaN      NaN        NaN
# 1948-04-01                           NaN       NaN      NaN        NaN
# ...                                  ...       ...      ...        ...
# 2022-10-01                           0.6  0.283145  1.14099   2.336994
# 2023-01-01                           2.1  0.881596  2.08053   0.837339
# 2023-04-01                           0.6  1.490864  1.88750   0.866408
# 2023-07-01                           1.5  0.285880  1.73614   0.809230
# 2023-10-01                           1.0       NaN      NaN        NaN
#
# Period       Romania  Russia  Saudi Arabia  South Africa
# 1947-04-01       NaN     NaN           NaN           NaN
# 1947-07-01       NaN     NaN           NaN           NaN
# 1947-10-01       NaN     NaN           NaN           NaN
# 1948-01-01       NaN     NaN           NaN           NaN
# 1948-04-01       NaN     NaN           NaN           NaN
# ...              ...     ...           ...           ...
# 2022-10-01  1.223659     NaN      1.164417     -1.094064
# 2023-01-01 -0.804894     NaN     -1.116411      0.406619
# 2023-04-01  1.548405     NaN     -0.505205      0.457335
# 2023-07-01  0.887211     NaN     -3.176124     -0.247545
# 2023-10-01       NaN     NaN      0.400000           NaN
#
# [307 rows x 56 columns]

# %%
df_gdp.columns
# Out:
# Index(['Australia', 'Austria', 'Belgium', 'Canada', 'Chile', 'Colombia',
#        'Costa Rica', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France',
#        'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Israel', 'Italy',
#        'Japan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Mexico',
#        'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
#        'Slovak Republic', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
#        'Türkiye', 'United Kingdom', 'United States',
#        'European Union – 27 countries (from 01/02/2020)',
#        'Euro area (20 countries)', 'G7', 'NAFTA', 'OECD - Europe', 'G20',
#        'OECD - Total', 'Argentina', 'Brazil', 'Bulgaria',
#        'China (People's Republic of)', 'Croatia', 'India', 'Indonesia',
#        'Romania', 'Russia', 'Saudi Arabia', 'South Africa'],
#       dtype='object', name='Period')

# %%
# Add median column
df_gdp['median'] = df_gdp.median(axis=1)

# %%
# Names of countries
countries = ['Australia', 'Austria', 'Belgium', 'Canada', 'Chile', 'Colombia',
       'Costa Rica', 'Czechia', 'Denmark', 'Estonia', 'Finland', 'France',
       'Germany', 'Greece', 'Hungary', 'Iceland', 'Ireland', 'Israel', 'Italy',
       'Japan', 'Korea', 'Latvia', 'Lithuania', 'Luxembourg', 'Mexico',
       'Netherlands', 'New Zealand', 'Norway', 'Poland', 'Portugal',
       'Slovak Republic', 'Slovenia', 'Spain', 'Sweden', 'Switzerland',
       'Türkiye', 'United Kingdom', 'United States', 'Argentina', 'Brazil', 'Bulgaria',
       "China (People's Republic of)", 'Croatia', 'India', 'Indonesia',
       'Romania', 'Russia', 'Saudi Arabia', 'South Africa']

# %%
# Count the number of countries for which there is data (not NaN for each quarter)
df_gdp['count'] = df_gdp[countries].count(axis=1)

# %%
df_gdp['count'].plot()
# Out:
# <Axes: >

# %%
df_gdp = df_gdp.apply(pd.to_numeric, errors='coerce').dropna()
df_gdp.plot()
# Out:
# <Axes: >

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from seminartools.data import read_gdp_growth

df = read_gdp_growth()
df
# Out:
# Period      Australia   Austria   Belgium    Canada     Chile  Colombia  \
# 1947-04-01        NaN       NaN       NaN       NaN       NaN       NaN
# 1947-07-01        NaN       NaN       NaN       NaN       NaN       NaN
# 1947-10-01        NaN       NaN       NaN       NaN       NaN       NaN
# 1948-01-01        NaN       NaN       NaN       NaN       NaN       NaN
# 1948-04-01        NaN       NaN       NaN       NaN       NaN       NaN
# ...               ...       ...       ...       ...       ...       ...
# 2022-10-01   0.854933 -0.109469  0.242596 -0.215348  0.134982 -1.636127
# 2023-01-01   0.533364  0.091308  0.413039  0.610026  0.546959  2.171743
# 2023-04-01   0.438743 -1.109172  0.332990  0.338964 -0.348738 -0.988247
# 2023-07-01   0.211980 -0.518956  0.381116 -0.266630  0.331248  0.238780
# 2023-10-01        NaN  0.230333  0.420257  0.300000       NaN       NaN
#
# Period      Costa Rica   Czechia   Denmark   Estonia  ...  Bulgaria  \
# 1947-04-01         NaN       NaN       NaN       NaN  ...       NaN
# 1947-07-01         NaN       NaN       NaN       NaN  ...       NaN
# 1947-10-01         NaN       NaN       NaN       NaN  ...       NaN
# 1948-01-01         NaN       NaN       NaN       NaN  ...       NaN
# 1948-04-01         NaN       NaN       NaN       NaN  ...       NaN
# ...                ...       ...       ...       ...  ...       ...
# 2022-10-01    2.252222 -0.355478  0.129033 -1.436173  ...  0.585075
# 2023-01-01   -0.584824  0.113500  0.906018 -0.777569  ...  0.349776
# 2023-04-01    2.504614  0.080160 -0.699459 -0.600577  ...  0.412767
# 2023-07-01    1.286147 -0.631639 -0.652085 -1.293712  ...  0.396863
# 2023-10-01    1.781322  0.232706       NaN -0.365528  ...       NaN
#
# Period      China (People's Republic of)   Croatia    India  Indonesia  \
# 1947-04-01                           NaN       NaN      NaN        NaN
# 1947-07-01                           NaN       NaN      NaN        NaN
# 1947-10-01                           NaN       NaN      NaN        NaN
# 1948-01-01                           NaN       NaN      NaN        NaN
# 1948-04-01                           NaN       NaN      NaN        NaN
# ...                                  ...       ...      ...        ...
# 2022-10-01                           0.6  0.283145  1.14099   2.336994
# 2023-01-01                           2.1  0.881596  2.08053   0.837339
# 2023-04-01                           0.6  1.490864  1.88750   0.866408
# 2023-07-01                           1.5  0.285880  1.73614   0.809230
# 2023-10-01                           1.0       NaN      NaN        NaN
#
# Period       Romania  Russia  Saudi Arabia  South Africa    median
# 1947-04-01       NaN     NaN           NaN           NaN -0.265224
# 1947-07-01       NaN     NaN           NaN           NaN -0.204879
# 1947-10-01       NaN     NaN           NaN           NaN  1.565987
# 1948-01-01       NaN     NaN           NaN           NaN  1.506038
# 1948-04-01       NaN     NaN           NaN           NaN  1.652377
# ...              ...     ...           ...           ...       ...
# 2022-10-01  1.223659     NaN      1.164417     -1.094064  0.134982
# 2023-01-01 -0.804894     NaN     -1.116411      0.406619  0.406619
# 2023-04-01  1.548405     NaN     -0.505205      0.457335  0.412767
# 2023-07-01  0.887211     NaN     -3.176124     -0.247545  0.144535
# 2023-10-01       NaN     NaN      0.400000           NaN  0.232706
#
# [307 rows x 57 columns]
