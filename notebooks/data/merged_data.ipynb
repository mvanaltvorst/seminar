# %%
# %load_ext autoreload
# %autoreload 2

# %%
from seminartools.data import read_inflation, read_commodity, read_gdp_growth, read_interest_rate, read_unemployment
import pandas as pd

dfs = {
    'inflation': read_inflation(mergeable_format=True),
    'commodity': read_commodity(mergeable_format=True),
    'gdp_growth': read_gdp_growth(mergeable_format=True),
    'interest_rate': read_interest_rate(mergeable_format=True),
    'unemployment': read_unemployment(mergeable_format=True),
}

# %%
dfs["commodity"]
# Out:
#             commodity_CRUDE_PETRO  commodity_iNATGAS  commodity_iAGRICULTURE  \
# date
# 1977-01-01               0.000000           0.052425                0.144757
# 1977-04-01              -0.004000           0.043586               -0.066688
# 1977-07-01               0.014458           0.005967               -0.145538
# 1977-10-01               0.003959           0.005931                0.040048
# 1978-01-01              -0.001577           0.156056                0.072482
# ...                           ...                ...                     ...
# 2022-04-01               0.039177          -0.028903               -0.029440
# 2022-07-01              -0.244692           0.486523               -0.088860
# 2022-10-01              -0.115091          -0.355721               -0.016280
# 2023-01-01              -0.020410          -0.585458                0.002037
# 2023-04-01              -0.030730          -0.199820               -0.005889
#
#             commodity_iMETMIN  commodity_iPRECIOUSMET
# date
# 1977-01-01           0.041940                0.112740
# 1977-04-01          -0.045412               -0.060029
# 1977-07-01           0.019138                0.045236
# 1977-10-01           0.046373                0.065161
# 1978-01-01          -0.002346                0.139776
# ...                       ...                     ...
# 2022-04-01          -0.181045               -0.072004
# 2022-07-01          -0.154988               -0.090042
# 2022-10-01           0.100554                0.093372
# 2023-01-01           0.007418                0.043183
# 2023-04-01          -0.072743                0.051231
#
# [186 rows x 5 columns]

# %%
df = pd.concat([
    dfs['inflation'],
    #dfs['commodity'],
    dfs['gdp_growth'],
    dfs['interest_rate'],
    dfs['unemployment'],
], axis=1).join( # join level 1 of the multiindex with the commodity data
    dfs['commodity'],
    on='date',
)
df.dropna()
# Out:
#                           inflation  gdp_growth  interest_rate  \
# country       date
# Japan         1977-01-01   0.022951    2.187257       6.333333
# Canada        1977-01-01   0.023904    1.533830       8.166667
# United States 1977-01-01   0.017231    1.186233       4.700000
# Japan         1977-04-01   0.027244    0.703788       5.000000
# Canada        1977-04-01   0.023346    0.510302       7.666667
# ...                             ...         ...            ...
# Switzerland   2023-01-01   0.010084    0.309543       1.166667
# Canada        2023-01-01   0.006080    0.610026       4.500000
# Sweden        2023-01-01   0.014955    0.656897       2.833333
# Korea         2023-01-01   0.010538    0.329875       3.500000
# South Africa  2023-01-01   0.011202    0.406619       7.416667
#
#                           unemployment_rate  commodity_CRUDE_PETRO  \
# country       date
# Japan         1977-01-01                2.3                0.00000
# Canada        1977-01-01                8.8                0.00000
# United States 1977-01-01                8.2                0.00000
# Japan         1977-04-01                2.0               -0.00400
# Canada        1977-04-01                8.0               -0.00400
# ...                                     ...                    ...
# Switzerland   2023-01-01                4.4               -0.02041
# Canada        2023-01-01                5.4               -0.02041
# Sweden        2023-01-01                7.8               -0.02041
# Korea         2023-01-01                3.2               -0.02041
# South Africa  2023-01-01               28.1               -0.02041
#
#                           commodity_iNATGAS  commodity_iAGRICULTURE  \
# country       date
# Japan         1977-01-01           0.052425                0.144757
# Canada        1977-01-01           0.052425                0.144757
# United States 1977-01-01           0.052425                0.144757
# Japan         1977-04-01           0.043586               -0.066688
# Canada        1977-04-01           0.043586               -0.066688
# ...                                     ...                     ...
# Switzerland   2023-01-01          -0.585458                0.002037
# Canada        2023-01-01          -0.585458                0.002037
# Sweden        2023-01-01          -0.585458                0.002037
# Korea         2023-01-01          -0.585458                0.002037
# South Africa  2023-01-01          -0.585458                0.002037
#
#                           commodity_iMETMIN  commodity_iPRECIOUSMET
# country       date
# Japan         1977-01-01           0.041940                0.112740
# Canada        1977-01-01           0.041940                0.112740
# United States 1977-01-01           0.041940                0.112740
# Japan         1977-04-01          -0.045412               -0.060029
# Canada        1977-04-01          -0.045412               -0.060029
# ...                                     ...                     ...
# Switzerland   2023-01-01           0.007418                0.043183
# Canada        2023-01-01           0.007418                0.043183
# Sweden        2023-01-01           0.007418                0.043183
# Korea         2023-01-01           0.007418                0.043183
# South Africa  2023-01-01           0.007418                0.043183
#
# [1529 rows x 9 columns]

# %% [markdown]
# # Figure out countries

# %%
from collections import Counter, defaultdict
from pprint import pprint

def get_country_stats(country_lists: dict[str, list[str]]):
    """
    We find 
    1. Overlapping countries
    2. Countries within a country list that do not appear in any other country list
    3. Countries that appear in all other country lists but not in the current one
    """
    n = len(country_lists)

    counter = Counter()
    containing_lists = defaultdict(list)
    for country_list in country_lists.values():
        counter.update(country_list)


    unique_countries = {}
    missing_countries = {}
    for name, country_list in country_lists.items():
        # find countries that are in the current list but do not have 5 counts in the counter
        unique_countries[name] = [country for country in country_list if counter[country] == 1 and country in country_list]
        missing_countries[name] = [country for country in counter if counter[country] == n and country not in country_list]
        for country in country_list:
            containing_lists[country].append(name)

    return counter, unique_countries, missing_countries, containing_lists

counter, unique_countries, missing_countries, containing_lists = get_country_stats({
    'inflation': dfs['inflation'].index.get_level_values(0).unique().tolist(),
    'gdp_growth': dfs['gdp_growth'].index.get_level_values(0).unique().tolist(),
    'interest_rate': dfs['interest_rate'].index.get_level_values(0).unique().tolist(),
    'unemployment': dfs['unemployment'].index.get_level_values(0).unique().tolist(),
})
print("Countries that are contained in all 4 datasets:")
pprint([country for country in counter if counter[country] == 4])
print(f"In total: {len([country for country in counter if counter[country] == 4])} countries")
# Out:
# Countries that are contained in all 4 datasets:
# ['Portugal',
#  'New Zealand',
#  'Japan',
#  'South Africa',
#  'Korea',
#  'Sweden',
#  'Switzerland',
#  'France',
#  'Denmark',
#  'Netherlands',
#  'Türkiye',
#  'Germany',
#  'Norway',
#  'Belgium',
#  'United States',
#  'Canada',
#  'Italy',
#  'United Kingdom',
#  'Australia',
#  'Spain']
# In total: 20 countries

# %%
containing_lists = sorted(list(dict(containing_lists).items()), key=lambda x: len(x[1]), reverse=True)
print("Countries and the datasets they are contained in:")
containing_lists
# Out:
# Countries and the datasets they are contained in:
# [('Portugal', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('New Zealand', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Japan', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('South Africa',
#   ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Korea', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Sweden', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Switzerland', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('France', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Denmark', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Netherlands', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Türkiye', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Germany', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Norway', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Belgium', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('United States',
#   ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Canada', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Italy', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('United Kingdom',
#   ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Australia', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Spain', ['inflation', 'gdp_growth', 'interest_rate', 'unemployment']),
#  ('Finland', ['inflation', 'gdp_growth', 'unemployment']),
#  ('Ireland', ['inflation', 'gdp_growth', 'unemployment']),
#  ('Austria', ['inflation', 'gdp_growth', 'unemployment']),
#  ('Thailand', ['inflation', 'interest_rate', 'unemployment']),
#  ('Greece', ['inflation', 'gdp_growth', 'unemployment']),
#  ('Luxembourg', ['inflation', 'gdp_growth', 'unemployment']),
#  ('Philippines', ['inflation', 'interest_rate', 'unemployment']),
#  ('Iceland', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Mexico', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Indonesia', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Argentina', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Czechia', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Hungary', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Israel', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Poland', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Croatia', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Romania', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Chile', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Brazil', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('India', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Russia', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Colombia', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Saudi Arabia', ['gdp_growth', 'interest_rate', 'unemployment']),
#  ('Dominican Republic', ['inflation', 'unemployment']),
#  ('Paraguay', ['inflation', 'unemployment']),
#  ('Malaysia', ['inflation', 'interest_rate']),
#  ('Cyprus', ['inflation', 'unemployment']),
#  ('Mauritius', ['inflation', 'unemployment']),
#  ('Singapore', ['inflation', 'unemployment']),
#  ('Guatemala', ['inflation', 'unemployment']),
#  ('Costa Rica', ['gdp_growth', 'unemployment']),
#  ('Estonia', ['gdp_growth', 'unemployment']),
#  ('Latvia', ['gdp_growth', 'unemployment']),
#  ('Lithuania', ['gdp_growth', 'unemployment']),
#  ('Slovenia', ['gdp_growth', 'unemployment']),
#  ('Bulgaria', ['gdp_growth', 'unemployment']),
#  ('China', ['gdp_growth', 'interest_rate']),
#  ('Serbia', ['interest_rate', 'unemployment']),
#  ('North Macedonia', ['interest_rate', 'unemployment']),
#  ('Peru', ['interest_rate', 'unemployment']),
#  ('Fiji', ['inflation']),
#  ('OECD - Europe', ['gdp_growth']),
#  ('G7', ['gdp_growth']),
#  ('NAFTA', ['gdp_growth']),
#  ('OECD - Total', ['gdp_growth']),
#  ('Slovak Republic', ['gdp_growth']),
#  ('European Union – 27 countries (from 01/02/2020)', ['gdp_growth']),
#  ('Euro area (20 countries)', ['gdp_growth']),
#  ('G20', ['gdp_growth']),
#  ('Hong Kong SAR', ['interest_rate']),
#  ('Euro area', ['interest_rate']),
#  ('Morocco', ['interest_rate']),
#  ('Taiwan, China', ['unemployment']),
#  ('Bolivia', ['unemployment']),
#  ('Macau, China', ['unemployment']),
#  ('Slovakia', ['unemployment']),
#  ('Uruguay', ['unemployment']),
#  ('Occupied Palestinian Territory', ['unemployment']),
#  ('Malta', ['unemployment']),
#  ('Ecuador', ['unemployment']),
#  ('Venezuela, Bolivarian Republic of', ['unemployment']),
#  ('Iran, Islamic Republic of', ['unemployment']),
#  ('Egypt', ['unemployment']),
#  ('Jamaica', ['unemployment']),
#  ('Kyrgyzstan', ['unemployment']),
#  ('Sri Lanka', ['unemployment']),
#  ('Moldova, Republic of', ['unemployment']),
#  ('Mongolia', ['unemployment']),
#  ('Trinidad and Tobago', ['unemployment']),
#  ('Montenegro', ['unemployment']),
#  ('Viet Nam', ['unemployment']),
#  ('Albania', ['unemployment']),
#  ('Kosovo', ['unemployment']),
#  ('Nicaragua', ['unemployment']),
#  ('Pakistan', ['unemployment']),
#  ('Belize', ['unemployment']),
#  ('Armenia', ['unemployment']),
#  ('Yemen', ['unemployment']),
#  ('Seychelles', ['unemployment']),
#  ('Senegal', ['unemployment']),
#  ('Bangladesh', ['unemployment']),
#  ('Georgia', ['unemployment']),
#  ('Jordan', ['unemployment']),
#  ('Saint Lucia', ['unemployment']),
#  ('Myanmar', ['unemployment']),
#  ('Rwanda', ['unemployment']),
#  ('Zambia', ['unemployment']),
#  ('Guyana', ['unemployment']),
#  ('Grenada', ['unemployment']),
#  ('Kenya', ['unemployment']),
#  ('Botswana', ['unemployment']),
#  ('Bosnia and Herzegovina', ['unemployment']),
#  ('Zimbabwe', ['unemployment']),
#  ('Tunisia', ['unemployment']),
#  ('Nigeria', ['unemployment'])]

# %%
dfs["gdp_growth"].index.get_level_values(0).unique().tolist()
# Out:
# ['United States',
#  'United Kingdom',
#  'Australia',
#  'Austria',
#  'Belgium',
#  'Denmark',
#  'Finland',
#  'France',
#  'Germany',
#  'Greece',
#  'Iceland',
#  'Ireland',
#  'Italy',
#  'Japan',
#  'Korea',
#  'Luxembourg',
#  'Mexico',
#  'Netherlands',
#  'Norway',
#  'Portugal',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'South Africa',
#  'Canada',
#  'OECD - Europe',
#  'G7',
#  'NAFTA',
#  'OECD - Total',
#  'New Zealand',
#  'Indonesia',
#  'Costa Rica',
#  'Slovak Republic',
#  'Argentina',
#  'Czechia',
#  'Estonia',
#  'Hungary',
#  'Israel',
#  'Latvia',
#  'Lithuania',
#  'Poland',
#  'Slovenia',
#  'European Union – 27 countries (from 01/02/2020)',
#  'Euro area (20 countries)',
#  'Bulgaria',
#  'Croatia',
#  'Romania',
#  'Chile',
#  'Brazil',
#  'India',
#  'Türkiye',
#  'G20',
#  'Russia',
#  'Colombia',
#  'Saudi Arabia',
#  "China (People's Republic of)"]

# %% [markdown]
# # 4. work on excluding countries

# %%
from seminartools.data import read_merged
df = read_merged().reset_index()
df
# Out:
#             country       date  inflation  gdp_growth  interest_rate  \
# 0             Japan 1977-01-01   0.022951    2.187257       6.333333
# 1            Canada 1977-01-01   0.023904    1.533830       8.166667
# 2     United States 1977-01-01   0.017231    1.186233       4.700000
# 3             Japan 1977-04-01   0.027244    0.703788       5.000000
# 4            Canada 1977-04-01   0.023346    0.510302       7.666667
# ...             ...        ...        ...         ...            ...
# 2166          Italy 2023-01-01   0.003938    0.552944       3.000000
# 2167         Canada 2023-01-01   0.006080    0.610026       4.500000
# 2168         Sweden 2023-01-01   0.014955    0.656897       2.833333
# 2169          Korea 2023-01-01   0.010538    0.329875       3.500000
# 2170   South Africa 2023-01-01   0.011202    0.406619       7.416667
#
#       unemployment_rate  commodity_CRUDE_PETRO  commodity_iNATGAS  \
# 0                   2.3                0.00000           0.052425
# 1                   8.8                0.00000           0.052425
# 2                   8.2                0.00000           0.052425
# 3                   2.0               -0.00400           0.043586
# 4                   8.0               -0.00400           0.043586
# ...                 ...                    ...                ...
# 2166                8.3               -0.02041          -0.585458
# 2167                5.4               -0.02041          -0.585458
# 2168                7.8               -0.02041          -0.585458
# 2169                3.2               -0.02041          -0.585458
# 2170               28.1               -0.02041          -0.585458
#
#       commodity_iAGRICULTURE  commodity_iMETMIN  commodity_iPRECIOUSMET
# 0                   0.144757           0.041940                0.112740
# 1                   0.144757           0.041940                0.112740
# 2                   0.144757           0.041940                0.112740
# 3                  -0.066688          -0.045412               -0.060029
# 4                  -0.066688          -0.045412               -0.060029
# ...                      ...                ...                     ...
# 2166                0.002037           0.007418                0.043183
# 2167                0.002037           0.007418                0.043183
# 2168                0.002037           0.007418                0.043183
# 2169                0.002037           0.007418                0.043183
# 2170                0.002037           0.007418                0.043183
#
# [2171 rows x 11 columns]

# %%
countries = (df["country"].unique())
countries
select = df.country.apply(lambda x : x  not in countries)
dfs = df[select].copy()
dfs.set_index(['country', 'date']).reset_index()
dfs
# Out:
# Empty DataFrame
# Columns: [country, date, inflation, gdp_growth, interest_rate, unemployment_rate, commodity_CRUDE_PETRO, commodity_iNATGAS, commodity_iAGRICULTURE, commodity_iMETMIN, commodity_iPRECIOUSMET]
# Index: []

# %%
from seminartools.data import read_merged

d = read_merged(only_countries = ["Japan"]).reset_index()
d
# Out:
#      index country       date  inflation  gdp_growth  interest_rate  \
# 0        0   Japan 1977-01-01   0.022951    2.187257       6.333333
# 1        3   Japan 1977-04-01   0.027244    0.703788       5.000000
# 2        7   Japan 1977-07-01   0.003120    0.681687       4.750000
# 3       11   Japan 1977-10-01   0.010886    1.356457       4.250000
# 4       14   Japan 1978-01-01   0.004615    1.889185       4.000000
# ..     ...     ...        ...        ...         ...            ...
# 144   2090   Japan 2022-01-01   0.006876   -0.596637      -0.100000
# 145   2105   Japan 2022-04-01   0.009756    1.081749      -0.100000
# 146   2128   Japan 2022-07-01   0.010628   -0.096010      -0.100000
# 147   2152   Japan 2022-10-01   0.011252    0.248075      -0.100000
# 148   2159   Japan 2023-01-01   0.004500    1.227393      -0.100000
#
#      unemployment_rate  commodity_CRUDE_PETRO  commodity_iNATGAS  \
# 0                  2.3               0.000000           0.052425
# 1                  2.0              -0.004000           0.043586
# 2                  1.9               0.014458           0.005967
# 3                  1.9               0.003959           0.005931
# 4                  2.5              -0.001577           0.156056
# ..                 ...                    ...                ...
# 144                2.7               0.542498           0.146272
# 145                2.7               0.039177          -0.028903
# 146                2.6              -0.244692           0.486523
# 147                2.4              -0.115091          -0.355721
# 148                2.6              -0.020410          -0.585458
#
#      commodity_iAGRICULTURE  commodity_iMETMIN  commodity_iPRECIOUSMET
# 0                  0.144757           0.041940                0.112740
# 1                 -0.066688          -0.045412               -0.060029
# 2                 -0.145538           0.019138                0.045236
# 3                  0.040048           0.046373                0.065161
# 4                  0.072482          -0.002346                0.139776
# ..                      ...                ...                     ...
# 144                0.163679           0.210497                0.093645
# 145               -0.029440          -0.181045               -0.072004
# 146               -0.088860          -0.154988               -0.090042
# 147               -0.016280           0.100554                0.093372
# 148                0.002037           0.007418                0.043183
#
# [149 rows x 12 columns]

# %% [markdown]
# # 2. core inflation

# %%
from seminartools.data import read_merged

df_core = read_merged(coreInf=True).reset_index()
df_core
# Out:
#             country       date  ...  commodity_iMETMIN  commodity_iPRECIOUSMET
# 0     United States 1977-01-01  ...           0.041940                0.112740
# 1             Japan 1977-01-01  ...           0.041940                0.112740
# 2            Canada 1977-01-01  ...           0.041940                0.112740
# 3             Japan 1977-04-01  ...          -0.045412               -0.060029
# 4            Canada 1977-04-01  ...          -0.045412               -0.060029
# ...             ...        ...  ...                ...                     ...
# 1317        Germany 2023-01-01  ...           0.007418                0.043183
# 1318    Switzerland 2023-01-01  ...           0.007418                0.043183
# 1319         Canada 2023-01-01  ...           0.007418                0.043183
# 1320         Sweden 2023-01-01  ...           0.007418                0.043183
# 1321  United States 2023-01-01  ...           0.007418                0.043183
#
# [1322 rows x 11 columns]

# %%
df_headline = read_merged().reset_index()
df_headline
# Out:
#             country       date  ...  commodity_iMETMIN  commodity_iPRECIOUSMET
# 0             Japan 1977-01-01  ...           0.041940                0.112740
# 1            Canada 1977-01-01  ...           0.041940                0.112740
# 2     United States 1977-01-01  ...           0.041940                0.112740
# 3             Japan 1977-04-01  ...          -0.045412               -0.060029
# 4            Canada 1977-04-01  ...          -0.045412               -0.060029
# ...             ...        ...  ...                ...                     ...
# 2166          Italy 2023-01-01  ...           0.007418                0.043183
# 2167         Canada 2023-01-01  ...           0.007418                0.043183
# 2168         Sweden 2023-01-01  ...           0.007418                0.043183
# 2169          Korea 2023-01-01  ...           0.007418                0.043183
# 2170   South Africa 2023-01-01  ...           0.007418                0.043183
#
# [2171 rows x 11 columns]

# %%
len(df_core['country'].unique())
# Out:
# 12

# %%
df_headline['country'].unique()
# Out:
# array(['Japan', 'Canada', 'United States', 'Australia', 'New Zealand',
#        'Switzerland', 'Italy', 'France', 'Portugal', 'Spain', 'Sweden',
#        'Denmark', 'United Kingdom', 'Germany', 'Netherlands', 'Norway',
#        'Belgium', 'Korea', 'South Africa', 'Türkiye'], dtype=object)
